# %%
import pandas as pd

# %%
data = [['A', 'Math'], ['B', 'English'], ['C', 'Math'], ['D', 'Biology'], ['E', 'Math'], ['F', 'Computer'], ['G', 'Math'], ['H', 'Math'], ['I', 'Math']]
courses = pd.DataFrame(data, columns=['student', 'class']).astype({'student':'object', 'class':'object'})

# %%
def find_classes(courses: pd.DataFrame) -> pd.DataFrame:
    # grouped = courses.groupby('class').filter(lambda x: len(x)>4).drop_duplicates(subset=['class'])
    # return grouped[['class']]
    grouped = courses.groupby("class").size().reset_index(name="counts")
    return grouped[grouped["counts"] > 4][["class"]]

# %%
print(find_classes(courses))
# Out:
#   class
# 3  Math
